# %%
custom_rules = [
    #chief_complaint 
    SectionRule("CHIEF COMPLAINT(S)", "chief_complaint"),
    SectionRule("CHIEF COMPLAINTS", "chief_complaint"),
    SectionRule("CHIEF COMPLAINT", "chief_complaint"),
    SectionRule("CHIEF COMPLAINT(Required)", "chief_complaint"),
    SectionRule("Chief Complaint(s):", "chief_complaint"),
    SectionRule("Chief Complaints:", "chief_complaint"),
    SectionRule("Chief Complaint:", "chief_complaint"),
    SectionRule("Chief complaint(s):", "chief_complaint"),
    SectionRule("Chief complaints:", "chief_complaint"),
    SectionRule("Chief complaint:", "chief_complaint"),
    SectionRule("chief Complaint(s):", "chief_complaint"),
    SectionRule("chief Complaints:", "chief_complaint"),
    SectionRule("chief Complaint:", "chief_complaint"),
    SectionRule("REASON FOR VISIT", "chief_complaint"),
    SectionRule("Reason for consult:", "chief_complaint"),
    SectionRule("Reason for Consult:", "chief_complaint"),
    SectionRule("Chief complaint/patient stated reason for visit", "chief_complaint"),
    SectionRule("Patient's reason for visit:", "chief_complaint"),
    SectionRule("Subjective/Chief Complaint:", "chief_complaint"),
    SectionRule("Primary DMP:", "chief_complaint"),
    
    #history_of_present_illness
    SectionRule("History of Present Illness", "history_of_present_illness"),
    SectionRule("HX PRESENT ILLNESS", "history_of_present_illness"),
    SectionRule("HISTORY:", "history_of_present_illness"),
    SectionRule("History of the Present Illness", "history_of_present_illness"),
    SectionRule(">>>HISTORY", "history_of_present_illness"),
    SectionRule("History of CC", "history_of_present_illness"),
    SectionRule("History of cc", "history_of_present_illness"),
    SectionRule("HPI", "history_of_present_illness"),
    SectionRule("SUBJECTIVE:", "history_of_present_illness"),
    SectionRule("Subjective:", "history_of_present_illness"),
    SectionRule("Subject:", "history_of_present_illness"),
    SectionRule(">>SUBJECTIVE<<", "history_of_present_illness"),
    SectionRule("presents with:", "history_of_present_illness"),
    SectionRule("Reason for Request:", "history_of_present_illness"),
    SectionRule("Reason for Admission:", "history_of_present_illness"),
    SectionRule("Reason for admission:", "history_of_present_illness"),
    SectionRule("REASON FOR REQUEST:", "history_of_present_illness"),
    SectionRule("REASON FOR REQUEST", "history_of_present_illness"),
    SectionRule("HIP/ROS:", "history_of_present_illness"),
    SectionRule("Focused Assessment:", "history_of_present_illness"),
    SectionRule("Nurse Notes", "history_of_present_illness"),
    SectionRule("History of Chief Complaint:", "history_of_present_illness"),
    
    #problem_list
    SectionRule("ACTIVE PROBLEMS", "problem_list"),
    SectionRule("Active Problems:", "problem_list"),
    SectionRule("Active Problems-", "problem_list"),
    SectionRule("ActivepProblems", "problem_list"),
    SectionRule("Computerized Problem List", "problem_list"),
    SectionRule("ACTIVE MEDICAL PROBLEMS", "problem_list"),
    SectionRule("ACTIVE PROBLEM LIST", "problem_list"),
    SectionRule("PROBLEM LIST/PAST MEDICAL HX:", "problem_list"),
    SectionRule("PROBLEMS LIST", "problem_list"),
    SectionRule(">>ACTIVE PROBLEM LIST<<", "problem_list"),
    SectionRule("Comorbidities:", "problem_list"),
    SectionRule("COMORBIDITIES", "problem_list"),
    SectionRule("Comorbid(s):", "problem_list"),
    
    #medications
    SectionRule("MEDICATION LIST:", "medications"),
    SectionRule("ACTIVE OUTPATIENT MEDICATIONS", "medications"),
    SectionRule("Active Outpatient Medications", "medications"),
    SectionRule("Outpatient Meds:", "medications"),
    SectionRule("ACTIVE INPATIENT MEDICATIONS", "medications"),
    SectionRule("Active Inpatient Medications", "medications"),
    SectionRule("Inpatient Medications", "medications"),
    SectionRule("Inpatient Meds:", "medications"),
    SectionRule("Active Medications", "medications"),
    SectionRule("ACTIVE MEDICATIONS", "medications"),
    SectionRule("Meds:", "medications"),
    SectionRule("MEDS:", "medications"),
    SectionRule(">>ACTIVER MEDS<<", "medications"),
    SectionRule("ANTIBIOTICS:", "medications"),
    SectionRule("CURRENT MEDS", "medications"),
    SectionRule("CURRENT MEDICATIONS", "medications"),
    SectionRule("Current Meds:", "medications"),
    SectionRule("Current Medications:", "medications"),
    SectionRule("MEDICATION", "medications"),
    SectionRule("MEDICATION RECONCILIATION", "medications"),
    SectionRule("Medication Reconciliation", "medications"),
    SectionRule("Outpatient Meds:", "medications"),
    SectionRule("MEDICATION REVIEW", "medications"),
    SectionRule("ORDERS CURRENT", "medications"),
    SectionRule("OUT PATIENT MEDICATIONS", "medications"),
    SectionRule("ACTIVE OUTPATIENT MEDS", "medications"),
    
    
    #social_history
    SectionRule("SOCIAL HISTORY", "social_history"),
    SectionRule("SOCIAL HISTORY/FAMILY HISTORY", "social_history"),
    SectionRule("Social history:", "social_history"),
    SectionRule("SOCIAL HX", "social_history"),
    SectionRule("SOCIAL Hx", "social_history"),
    SectionRule("SOChx", "social_history"),
    SectionRule("SOCIAL:", "social_history"),
    SectionRule("HABITS:", "social_history"),
    SectionRule("Substance History:", "social_history"),
    SectionRule(">>>S&FHx:", "social_history"),
    SectionRule("Shx -", "social_history"),
    SectionRule("SHX:", "social_history"),
    SectionRule("Travel Screen", "social_history"),
    
    #mental_health
    SectionRule("MENTAL STATUS EXAM", "mental_health"),
    SectionRule("MENTAL STATUS", "mental_health"),
    SectionRule("Mental Status Exam", "mental_health"),
    SectionRule("SUICIDE RISK ASSESSMENT", "mental_health"),
    SectionRule("Suicide Risk Assessment", "mental_health"),
    SectionRule("Suicide Screen:", "mental_health"),
    SectionRule("Suicide SCREEN:", "mental_health"),
    SectionRule("Mental Health Screen:", "mental_health"),
    SectionRule("LETHALITY ASSESSMENT SHEET", "mental_health"),
    SectionRule("C-SSRS Result", "mental_health"),
    SectionRule("MENTAL HEALTH", "mental_health"),
    
    #physical_exam
    SectionRule("PHYSICAL EXAMINATION", "physical_exam"),
    SectionRule("PHYSICAL EXAM", "physical_exam"),
    SectionRule("Physical Examination", "physical_exam"),
    SectionRule("Physical Exam", "physical_exam"),
    SectionRule("PE:", "physical_exam"),
    SectionRule("P.E.", "physical_exam"),
    SectionRule("PHYSICAL:", "physical_exam"),
    SectionRule("EXAMINATION:", "physical_exam"),
    SectionRule("EXAM:", "physical_exam"),
    SectionRule("Vital Signs:", "physical_exam"),
    SectionRule("VITALS", "physical_exam"),
    SectionRule("Vitals:", "physical_exam"),
    SectionRule("VITAL SIGNS:", "physical_exam"),
    SectionRule("VS:", "physical_exam"),
    SectionRule("OBJECTIVE", "physical_exam"),
    SectionRule("Objective:", "physical_exam"),
    SectionRule("Object:", "physical_exam"),
    SectionRule("O", "physical_exam"),
    SectionRule("Assessments and Scores", "physical_exam"),

    #Pain
    SectionRule("Pain Assessment", "pain"),
    SectionRule("PAIN ASSESSMENT", "pain"),
    SectionRule("Pain Screen:", "pain"),
    SectionRule("Pain Severity on arrival:", "pain"),
    
    
    #review_of_systems
    SectionRule("REVIEW OF SYSTEMS", "review_of_systems"),
    SectionRule("REVIEW OF SYSTEM", "review_of_systems"),
    SectionRule("Review of Systems", "review_of_systems"),
    SectionRule("ROS:", "review_of_systems"),
    SectionRule("ROS -", "review_of_systems"),
    SectionRule("SYSTEMS ASSESSMENTS", "review_of_systems"),
    
    #past_medical_history
    SectionRule("PREVIOUS MEDICAL HISTORY", "past_medical_history"),
    SectionRule("PAST MEDICAL HISTORY", "past_medical_history"),
    SectionRule("PAST MEDICAL HX", "past_medical_history"),
    SectionRule("PAST MEDICAL/SURGICAL HISTORY:", "past_medical_history"),
    SectionRule("Prior Medical/Surgical History", "past_medical_history"),
    SectionRule("SURGICAL HISTORY", "past_medical_history"),
    SectionRule("PMH/PSH", "past_medical_history"),
    SectionRule("Past Med/Surg Hx", "past_medical_history"),
    SectionRule("RECORD REVIEW:", "past_medical_history"),
    SectionRule("PMHx", "past_medical_history"),
    SectionRule("Past Medical Illness:", "past_medical_history"),
    SectionRule("Chronic Medical Diagnosis", "past_medical_history"),
    SectionRule("CHRONIC MEDICAL DIAGNOSIS", "past_medical_history"),
    SectionRule("MEDICAL HISTORY", "past_medical_history"),
    SectionRule("PAST MEDICAL and PAST SURGICAL HISTORY", "past_medical_history"),
    
    #allergy
    SectionRule("ALLERGY/ADR", "allergy"),
    SectionRule("Allergies:", "allergy"),
    SectionRule("ALLERGIES", "allergy"),
    SectionRule("ALLERGIES/ADVERSE REACTIONS", "allergy"),
    SectionRule("Allergies/Adverse Reactions", "allergy"),
    SectionRule("Allergies/ADR", "allergy"),
    SectionRule("Allergy assessment", "allergy"),
    SectionRule("Allergy Assessment", "allergy"),
    SectionRule("Current known allergies:", "allergy"),
    SectionRule("ALLERGY:", "allergy"),

    
    #hospital_course
    SectionRule("ED COURSE", "hospital_course"),
    SectionRule("ED Course", "hospital_course"),
    SectionRule("ED course:", "hospital_course"),
    SectionRule("CONSULTATION:", "hospital_course"),
    SectionRule("ER COURSE & PLAN", "hospital_course"),
    SectionRule("DAILY ORDER SUMMARY", "hospital_course"),
    SectionRule("ED INTERVENTIONS", "hospital_course"),
    SectionRule("ER TREATMENT/COURSE", "hospital_course"),
    
    #medical_decision_making
    SectionRule("MEDICAL DECISION MAKING", "medical_decision_making"),
    SectionRule("Medical Decision Making", "medical_decision_making"),
    SectionRule("DECISION MAKING", "medical_decision_making"),
    SectionRule("Decision Making:", "medical_decision_making"),
    SectionRule("MDM:", "medical_decision_making"),
    SectionRule("CLINICAL DECISION MAKING", "medical_decision_making"),
    SectionRule("linical Decision Making", "medical_decision_making"),
    SectionRule("ED COURSE/MEDICAL DECISION-MAKING", "medical_decision_making"),
    
    #labs_and_studies
    SectionRule("LABS:", "labs_and_studies"),
    SectionRule("Labs:", "labs_and_studies"),
    SectionRule("LABS", "labs_and_studies"),
    SectionRule("LAB:", "labs_and_studies"),
    SectionRule("Lab:", "labs_and_studies"),
    SectionRule("-LABS-", "labs_and_studies"),
    SectionRule("DIAGNOSTICS:", "labs_and_studies"),
    SectionRule("* LAB *", "labs_and_studies"),
    SectionRule("DIAGNOSTIC RESULTS", "labs_and_studies"),
    SectionRule("MICROBIOLOGY", "labs_and_studies"),
    SectionRule("LAB WORK WITHIN LAST 24 HOURS", "labs_and_studies"),
    SectionRule("Last 48 Hrs Lab Results", "labs_and_studies"),
    SectionRule("ORDERS PLACED", "labs_and_studies"),
    SectionRule("LABORATORY", "labs_and_studies"),
    SectionRule("LABORATORIES", "labs_and_studies"),
    SectionRule("Laboratories", "labs_and_studies"),
    SectionRule("PERTINENT LABS/DIAGNOSTIC FINDINGS:", "labs_and_studies"),
    SectionRule("Pertinent Laboratory:", "labs_and_studies"),
    SectionRule(">>LABORATORIES<<", "labs_and_studies"),
    SectionRule("Test name", "labs_and_studies"),
    SectionRule("Report Released Date/Time:", "labs_and_studies"),
    SectionRule("Reporting Lab:", "labs_and_studies"),
    SectionRule("LAB WORK FOR TODAY", "labs_and_studies"),
    SectionRule("Labs last 24 hrs:", "labs_and_studies"),
    SectionRule("INVESTIGATIONS", "labs_and_studies"),
    SectionRule("Specimen Collection Date:", "labs_and_studies"),
    SectionRule("MISCELLANEOUS TESTS", "labs_and_studies"),
    SectionRule("- URINALYSIS -", "labs_and_studies"),
    SectionRule("LAB DATA REVIEW", "labs_and_studies"),
    SectionRule("METABOLIC PANEL", "labs_and_studies"),
    SectionRule("Cultures:", "labs_and_studies"),
    SectionRule("Measurements:", "labs_and_studies"),
    
    #imaging
    SectionRule("RADIOLOGY", "imaging"),
    SectionRule("Radiology:", "imaging"),
    SectionRule("IMAGING/STUDIES", "imaging"),
    SectionRule("Imaging:", "imaging"),
    SectionRule("IMAGING", "imaging"),
    SectionRule("Impression:", "imaging"),
    SectionRule("Report Status: Verified", "imaging"),
    SectionRule("IMPRESSIONS", "imaging"),
    SectionRule("IMPRESSION", "imaging"),
    SectionRule("Impressions:", "imaging"),
    SectionRule("Imaiging Impression", "imaging"),
    SectionRule("FINDINGS:", "imaging"),
    SectionRule("EKGs and X-rays:", "imaging"),
    
    #comments
    SectionRule("Comments:", "comments"),
    SectionRule("N.B.", "comments"),
    SectionRule("Comment:", "comments"),
    
    #observation_and_plan
    SectionRule("SUMMARY", "observation_and_plan"),
    SectionRule("Summary:", "observation_and_plan"),
    SectionRule("PLANS", "observation_and_plans"),
    SectionRule("Plans:", "observation_and_plans"),
    SectionRule("PLAN", "observation_and_plan"),
    SectionRule("Plan:", "observation_and_plan"),
    SectionRule("PLAN/MEDICAL DECISION MAKING/ED COURSE", "observation_and_plan"),
    SectionRule("Assessment/Plan/Education", "observation_and_plan"),
    SectionRule("Assessment/Plan", "observation_and_plan"),
    SectionRule("ASSESSMENT AND PLAN", "observation_and_plan"),
    SectionRule("ASSESSMENT/PLAN", "observation_and_plan"),
    SectionRule("ASSESSMENT/IMPRESSION", "observation_and_plan"),
    SectionRule("Assessment/Impression:", "observation_and_plan"),
    SectionRule("ASSESSMENT/RECOMMENDATIONS", "observation_and_plan"),
    SectionRule("Assessment and Plan", "observation_and_plan"),
    SectionRule("RECOMMENDATIONS", "observation_and_plan"),
    SectionRule("RECOMMENDATIO:", "observation_and_plan"),
    SectionRule("Recommendations:", "observation_and_plan"),
    SectionRule("assessment and plan", "observation_and_plan"),
    SectionRule(">ASSESSMENT<", "observation_and_plan"),
    SectionRule("Imp.:", "observation_and_plan"),
    SectionRule(">>DIAGNOSTIC IMPRESSION<<", "observation_and_plan"),
    SectionRule("IMPRESSION AND ASSESSMENT", "observation_and_plan"),
    SectionRule("INITIAL IMPRESSION", "observation_and_plan"),
    SectionRule("Clinical Impression/Diagnosis:", "observation_and_plan"),
    SectionRule("IMPRESSION/Recommendations:", "observation_and_plan"),
    SectionRule("Final Impression:", "observation_and_plan"),
    SectionRule("IMPRESSION & RECOMMENDATIONS:", "observation_and_plan"),
    SectionRule("Impression & Recommendations:", "observation_and_plan"),
    SectionRule("CLINICAL IMPRESSION", "observation_and_plan"),
    SectionRule("Clinical Impression/Diagnosis:", "observation_and_plan"),
    SectionRule("Diagnostic Impression:", "observation_and_plan"),
    SectionRule("DIAGNOSTIC IMPRESSION", "observation_and_plan"),
    SectionRule("DIAGNOSIS/IMPRESSION", "observation_and_plan"),
    SectionRule("IMPRESSION/DX", "observation_and_plan"),
    SectionRule("Diagnosis:", "observation_and_plan"),
    SectionRule("ASSESSMENT:", "observation_and_plan"),
    SectionRule("ASSESSMENT/DIAGNOSIS", "observation_and_plan"),
    SectionRule("Assessment/Diagnosis:", "observation_and_plan"),
    SectionRule("REASSESSMENT", "observation_and_plan"),
    SectionRule("REASSESSED", "observation_and_plan"),
    SectionRule("DISPOSITION", "observation_and_plan"),
    SectionRule("Disposition:", "observation_and_plan"),
    SectionRule("DIAGNOSIS", "observation_and_plan"),
    SectionRule("Treatment and Plan:", "observation_and_plan"),
    SectionRule("Treatment Plan:", "observation_and_plan"),
    SectionRule("PLAN OF CARE:", "observation_and_plan"),
    SectionRule("PLAN OF CARE", "observation_and_plan"),
    SectionRule("Plan of Care:", "observation_and_plan"),
    SectionRule("Documented Primary team plan:", "observation_and_plan"),
    SectionRule("INTERVENTIONS:", "observation_and_plan"),
    SectionRule("INTERVENTION:", "observation_and_plan"),
    SectionRule("ACTION PLAN:", "observation_and_plan"),
    SectionRule("ACTION PLAN", "observation_and_plan"),
    SectionRule("Symptom Management:", "observation_and_plan"),
    SectionRule ("*ASSESSMENT* & *PLAN*", "observation_and_plan"),
               
    #specific
    SectionRule("New orders received", "observation_and_plan"),
    SectionRule("LV INTAE:", "other"),
    SectionRule("LV OUTPUT", "other"),
    SectionRule("Provider Info", "other"),
    SectionRule("Primary Interpreting Staff:", "other"),
    SectionRule("IDENTIFICATION DATA:", "other"),
    SectionRule("Teaching Assessment:", "patient_education"),
    SectionRule("PATIENT EDUCATION AT DISCHARGE", "patient_education"),
    SectionRule("PATIENT EDUCATION:", "patient_education"),
    SectionRule("ISOLATION PRECAUTIONS", "observation_and_plan"),
    SectionRule("ISOLATION CONTACT PRECAUTIONS", "observation_and_plan"),
    SectionRule("ACTIVITIES OF DAILY LIVING", "activities_of_daily_living"),
    SectionRule("ACTIVITIES OF DAILY LIVING:", "activities_of_daily_living"),
    SectionRule("[ACTIVITIES OF DAILY LIVING]", "activities_of_daily_living"),
    SectionRule("Abuse Screen", "other"),
    SectionRule("ABUSE SCREEN:", "other"),
    SectionRule("ABUSE/NEGLECT SCREEN:", "other"),
    SectionRule("FALLS RISK:", "other"),
    SectionRule("Falls Risk:", "other"),
    SectionRule("FALL RISK:", "other"),
    SectionRule("Fall Risk:", "other"),
    SectionRule("LEARNING READINESS:", "other"),
    SectionRule("Immunization History", "other"),
    SectionRule("IMMUNIZATIONS", "other"),
    SectionRule("F L O W S H E E T", "other"),
    SectionRule("[X]", "other"),
    SectionRule("Future Appointments:", "other"),
    SectionRule("Disclaimer:", "other"),
    SectionRule("DISCLAIMER:", "other"),
    SectionRule("CLINICAL REMINDER ACTIVITY", "other"),
    SectionRule("voice recognition", "other"),
    SectionRule("Voice recognition", "other"),
    SectionRule("FUTURE APPOINTMENTS:", "other"),
    SectionRule("Veteran Information:", "other"),
    SectionRule("Eligibility Verification:", "other"),
    SectionRule("IMPORTANT NOTICE TO ALL PATIENTS:", "other"),
    SectionRule("This Information Is About Your Illness and Diagnosis", "patient_education"),
    SectionRule("10-0386SCH", "other"),
    SectionRule("Has patient's identity been confirmed according to facility policy?", "other")
]
